# %%
#CODE TO GET PERCENTAGE CHANGES BY TREASURY ID
import pandas as pd
import os

# %%
#FEB 2024 CBO SPENDING PROJECTIONS
currentyr = 2024
years = [i for i in range(currentyr, currentyr+11)] 
cbo_ot = pd.read_excel('../data/cbo-2024-02-Spending-Projections.xlsx', header=7, sheet_name=1)
cbo_ot = cbo_ot[[col for col in cbo_ot.columns if col not in years]] #remove the BA cols
cbo_ot.columns = cbo_ot.columns.str.replace('.1', '')
cbo_ot = cbo_ot.drop(columns=['Unnamed: 9', "Unnamed: 21", "Off-Budget?"]).drop(index=0).drop(cbo_ot.index[-2:])
cbo_ot['25-34'] = cbo_ot.loc[:, '2025':'2034'].sum(axis=1)

cbo_ot["Agency"] = cbo_ot["Agency"].str.strip()
cbo_ot["Bureau"] = cbo_ot["Bureau"].str.strip()
cbo_ot['Title'] = cbo_ot['Title'].str.strip()

byprogram_24 = cbo_ot[["Treasury Identification Number", "25-34"]].groupby("Treasury Identification Number").sum()
byprogram_24.shape
# Out:
# (1686, 1)

# %%
cbo_ot.columns
# Out:
# Index(['Treasury Identification Number', 'Title', 'Discretionary or Mandatory',
#        'Major Spending Category', 'Agency', 'Bureau', 'Function',
#        'Subfunction', '2024', '2025', '2026', '2027', '2028', '2029', '2030',
#        '2031', '2032', '2033', '2034', '25-34'],
#       dtype='object')

# %%
#FEB 2021 CBO SPENDING PROJECTIONS
cbo21_ot = pd.read_excel('../data/cbo-2021-02-11-spendingprojections.xlsx', header=7, sheet_name=1)
years_21 = [i for i in range(2021, 2032)]
cbo21_ot = cbo21_ot[[col for col in cbo21_ot.columns if col not in years_21]].drop(columns=["Off-Budget?", "Unnamed: 9", "Unnamed: 21"]) #remove the BA cols, unnamed and unnecessary columns
cbo21_ot.columns = cbo21_ot.columns.str.replace('.1', '') #clean OT columns
cbo21_ot["22-31"] = cbo21_ot.loc[:, '2022':'2031'].sum(axis=1) #sum the years

byprogram_21 = cbo21_ot[["Treasury Identification Number", "22-31"]].groupby("Treasury Identification Number").sum() #group by agency-bureau-program and sum the total
byprogram_21.head(4)
# Out:
#                                 22-31
# Treasury Identification Number
# 000-0000-0-1-373                 4951
# 000-0000-0-1-604                 1000
# 000-0100-0-1-801                  381
# 000-0110-0-1-801                 2443

# %%
i = 0
y = 0
for tid24 in byprogram_24.index:
    if tid24 not in byprogram_21.index:
        i += 1
for tid21 in byprogram_21.index:
    if tid21 not in byprogram_24.index:
        y += 1
print("Total 2024 TIDs not in 2021 TIDs:", i)
print("Total 2021 TIDs not in 2024 TIDs:", y)
# Out:
# Total 2024 TIDs not in 2021 TIDs: 170
# Total 2021 TIDs not in 2024 TIDs: 125

# %%
#merge the two dataframes
merged = pd.merge(byprogram_21, byprogram_24, on="Treasury Identification Number", how="right")
merged['percent_change'] = ((merged['25-34'] - merged['22-31']) / abs(merged['22-31'])) * 100
merged.reset_index(inplace=True)
merged
# Out:
#      Treasury Identification Number   22-31   25-34  percent_change
# 0                  000-0100-0-1-801   381.0   351.0       -7.874016
# 1                  000-0110-0-1-801  2443.0  2819.0       15.390913
# 2                  000-0123-0-1-801   241.0   270.0       12.033195
# 3                  000-0126-0-1-801   110.0   193.0       75.454545
# 4                  000-0127-0-1-801  1523.0  1952.0       28.168089
# ...                             ...     ...     ...             ...
# 1681               576-9993-8-2-908     NaN  -570.0             NaN
# 1682               579-8299-0-7-552  6184.0  3961.0      -35.947607
# 1683               580-5585-0-2-376   571.0   391.0      -31.523643
# 1684               581-5577-0-2-376  5924.0  8835.0       49.139095
# 1685               581-5578-0-2-376   725.0  1907.0      163.034483
#
# [1686 rows x 4 columns]

# %%
with_info = pd.merge(merged, cbo_ot[["Treasury Identification Number","Agency", "Bureau", "Title"]], on="Treasury Identification Number", how="left")
with_info.drop_duplicates(keep='first', inplace=True)
with_info = with_info[['Treasury Identification Number', 'Agency', 'Bureau', 'Title', '22-31', '25-34', 'percent_change']]
with_info['22-31'] = with_info['22-31'].fillna('N/A')
with_info['percent_change'] = with_info['percent_change'].fillna('N/A')
with_info
# Out:
#      Treasury Identification Number  \
# 0                  000-0100-0-1-801
# 1                  000-0110-0-1-801
# 2                  000-0123-0-1-801
# 3                  000-0126-0-1-801
# 4                  000-0127-0-1-801
# ...                             ...
# 1945               576-9993-8-2-908
# 1946               579-8299-0-7-552
# 1947               580-5585-0-2-376
# 1948               581-5577-0-2-376
# 1949               581-5578-0-2-376
#
#                                              Agency  \
# 0                                Legislative Branch
# 1                                Legislative Branch
# 2                                Legislative Branch
# 3                                Legislative Branch
# 4                                Legislative Branch
# ...                                             ...
# 1945     Securities Investor Protection Corporation
# 1946  Patient-Centered Outcomes Research Trust Fund
# 1947               Corporation for Travel Promotion
# 1948        Bureau of Consumer Financial Protection
# 1949        Bureau of Consumer Financial Protection
#
#                                              Bureau  \
# 0                                            Senate
# 1                                            Senate
# 2                                            Senate
# 3                                            Senate
# 4                                            Senate
# ...                                             ...
# 1945     Securities Investor Protection Corporation
# 1946  Patient-Centered Outcomes Research Trust Fund
# 1947               Corporation for Travel Promotion
# 1948        Bureau of Consumer Financial Protection
# 1949        Bureau of Consumer Financial Protection
#
#                                               Title   22-31   25-34  \
# 0                   Compensation of members, Senate   381.0   351.0
# 1                  Salaries, officers and employees  2443.0  2819.0
# 2                               Miscellaneous items   241.0   270.0
# 3                           Secretary of the Senate   110.0   193.0
# 4     Sergeant at Arms and Doorkeeper of the Senate  1523.0  1952.0
# ...                                             ...     ...     ...
# 1945                  Earnings on investments, SIPC     N/A  -570.0
# 1946  Patient-Centered Outcomes Research Trust Fund  6184.0  3961.0
# 1947                          Travel Promotion Fund   571.0   391.0
# 1948   Bureau of Consumer Financial Protection Fund  5924.0  8835.0
# 1949          Consumer Financial Civil Penalty Fund   725.0  1907.0
#
#      percent_change
# 0         -7.874016
# 1         15.390913
# 2         12.033195
# 3         75.454545
# 4         28.168089
# ...             ...
# 1945            N/A
# 1946     -35.947607
# 1947     -31.523643
# 1948      49.139095
# 1949     163.034483
#
# [1686 rows x 7 columns]

# %%
with_info.query("Agency == 'Corps of Engineers--Civil Works'")
# Out:
#      Treasury Identification Number                           Agency  \
# 1710               096-3112-0-1-301  Corps of Engineers--Civil Works
# 1711               096-3121-0-1-301  Corps of Engineers--Civil Works
# 1712               096-3122-0-1-301  Corps of Engineers--Civil Works
# 1713               096-3123-0-1-301  Corps of Engineers--Civil Works
# 1714               096-3124-0-1-301  Corps of Engineers--Civil Works
# 1715               096-3125-0-1-301  Corps of Engineers--Civil Works
# 1716               096-3126-0-1-301  Corps of Engineers--Civil Works
# 1717               096-3128-0-1-301  Corps of Engineers--Civil Works
# 1718               096-3130-0-1-053  Corps of Engineers--Civil Works
# 1719               096-3132-0-1-301  Corps of Engineers--Civil Works
# 1720               096-3139-0-1-301  Corps of Engineers--Civil Works
# 1721               096-8217-0-7-306  Corps of Engineers--Civil Works
# 1722               096-8333-0-7-301  Corps of Engineers--Civil Works
# 1723               096-8861-0-7-301  Corps of Engineers--Civil Works
# 1724               096-8862-0-7-301  Corps of Engineers--Civil Works
# 1725               096-8862-8-7-301  Corps of Engineers--Civil Works
# 1726               096-8863-0-7-301  Corps of Engineers--Civil Works
# 1727               096-9921-0-2-301  Corps of Engineers--Civil Works
# 1728               096-9990-8-1-301  Corps of Engineers--Civil Works
# 1729               096-9990-8-1-303  Corps of Engineers--Civil Works
# 1730               096-9991-8-1-809  Corps of Engineers--Civil Works
# 1731               096-9991-8-1-908  Corps of Engineers--Civil Works
# 1732               096-9991-8-7-301  Corps of Engineers--Civil Works
#
#                                Bureau  \
# 1710  Corps of Engineers--Civil Works
# 1711  Corps of Engineers--Civil Works
# 1712  Corps of Engineers--Civil Works
# 1713  Corps of Engineers--Civil Works
# 1714  Corps of Engineers--Civil Works
# 1715  Corps of Engineers--Civil Works
# 1716  Corps of Engineers--Civil Works
# 1717  Corps of Engineers--Civil Works
# 1718  Corps of Engineers--Civil Works
# 1719  Corps of Engineers--Civil Works
# 1720  Corps of Engineers--Civil Works
# 1721  Corps of Engineers--Civil Works
# 1722  Corps of Engineers--Civil Works
# 1723  Corps of Engineers--Civil Works
# 1724  Corps of Engineers--Civil Works
# 1725  Corps of Engineers--Civil Works
# 1726  Corps of Engineers--Civil Works
# 1727  Corps of Engineers--Civil Works
# 1728  Corps of Engineers--Civil Works
# 1729  Corps of Engineers--Civil Works
# 1730  Corps of Engineers--Civil Works
# 1731  Corps of Engineers--Civil Works
# 1732  Corps of Engineers--Civil Works
#
#                                                   Title    22-31    25-34  \
# 1710                  Mississippi River and Tributaries   4670.0   4607.0
# 1711                                     Investigations   1860.0   1988.0
# 1712                                       Construction  33558.0  36207.0
# 1713                          Operation and maintenance  26231.0  41378.0
# 1714                                           Expenses   2472.0   2625.0
# 1715              Flood control and coastal emergencies    792.0   1552.0
# 1716                                 Regulatory program   2559.0   2807.0
# 1717                                Washington aqueduct    -10.0    371.0
# 1718    Formerly utilized sites remedial action program   2812.0   4472.0
# 1719  Office of the Assistant Secretary of the Army ...     47.0     57.0
# 1720  Water Infrastructure Finance and Innovation Pr...      N/A    144.0
# 1721  South Dakota terrestrial wildlife habitat rest...     30.0     30.0
# 1722            Coastal wetlands restoration trust fund    760.0    741.0
# 1723                        Inland Waterways Trust Fund   1266.0    233.0
# 1724               Rivers and harbors contributed funds   4275.0   5511.0
# 1725               Rivers and harbors contributed funds  -4700.0  -7000.0
# 1726                      Harbor maintenance trust fund  18827.0  25390.0
# 1727                           Permanent appropriations    120.0    121.0
# 1728  Receipts from leases of lands acq. for flood c...   -133.0   -165.0
# 1729            Recreation user fees, Corp of Engineers   -470.0   -694.0
# 1730                               Proprietary Receipts   -780.0  -1050.0
# 1731                               Proprietary Receipts   -210.0   -160.0
# 1732  User fees, fund for non-federal use of disposa...    -30.0    -20.0
#
#      percent_change
# 1710      -1.349036
# 1711        6.88172
# 1712       7.893796
# 1713      57.744653
# 1714        6.18932
# 1715      95.959596
# 1716       9.691286
# 1717         3810.0
# 1718      59.032717
# 1719      21.276596
# 1720            N/A
# 1721            0.0
# 1722           -2.5
# 1723     -81.595577
# 1724      28.912281
# 1725      -48.93617
# 1726       34.85951
# 1727       0.833333
# 1728      -24.06015
# 1729     -47.659574
# 1730     -34.615385
# 1731      23.809524
# 1732      33.333333

# %%
non_float_values = with_info[~with_info['percent_change'].apply(lambda x: isinstance(x, float))].query('percent_change != "N/A"')
inf_values = with_info[with_info['percent_change'].isin([float('inf'), float('-inf')])]
inf_values.shape
# Out:
# (14, 7)

# %%
with_info = with_info.replace([float('inf'), float('-inf')], float('nan'))
print(with_info.shape)
with_info = with_info.dropna()
print(with_info.shape)
# Out:
# (1686, 7)
# (1672, 7)

# %%
sheetname = "changes by TIN"
filename = "output/cbo_projection_changes.xlsx"
df = with_info
with pd.ExcelWriter(filename, mode='a', engine="openpyxl") as writer:
    df.to_excel(writer, sheet_name=sheetname, index=False)
